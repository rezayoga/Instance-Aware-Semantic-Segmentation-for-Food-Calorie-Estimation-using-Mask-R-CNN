# %% [markdown]
# ## Equations
#
#
# ---
#
#
# ESTIMASI KALORI CITRA MAKANAN BERBASIS INSTANCE SEGMENTATION MENGGUNAKAN MASK R-CNN
#
# By: Reza Yogaswara

# %% [markdown]
# $p = \frac{1}{1 + e^{(-y)}}$

# %% [markdown]
# ${Persentase \ Error}$ = ${Jumlah \ Kalori \ Ground \ Truth} - {Jumlah \ Kalori \ Prediksi}$ * $\frac{100}{Jumlah \ Kalori \ Ground \ Truth}$

# %% [markdown]
# ${Persentase \ Akurasi}$ = ${100} - {Persentase \ Error}$

# %% [markdown]
# ${Luas \ Obyek \ Sesungguhnya}$ = $\frac{Luas \ Piring \ Sesungguhnya}{Luas \ Piring \ pada \ Citra}$ ${Luas \ Obyek \ pada \ Citra}$

# %% [markdown]
# ${Volume \ Obyek}$ = ${Luas \ Obyek \ Sesungguhnya}$ *  ${Tinggi \ Obyek}$

# %% [markdown]
# ${Massa \ Obyek}$ = ${Massa \ Jenis \ Obyek} * {Volume \ Obyek}$

# %% [markdown]
# ${Jumlah \ Kalori \ Obyek}$ = $\frac{Massa \ Obyek}{Massa \ Obyek \ pada \ Tabel \ Kalori}$ ${Jumlah \ Kalori \ pada \ Table \ Acuan}$

# %% [markdown]
# $p = \frac{1}{1 + e^{(b_0 + b_1x)}}$

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# $\sum_{i=0}^n i^2 = \frac{(n^2+n)(2n+1)}{6}$

# %% [markdown]
# $\frac {p}{1-p} = exp(b_0 + b_1x)$

# %% [markdown]
# $p(y=1|x) = \frac {e^{(b_0 + b_1x)}}{1 + e^{(b_0 + b_1x)}} = \frac{1}{1 + e^{(-y)}}$

# %% [markdown]
# $p(y=1|x) = 1\quad\mathsf {if}\quad b_1x \ge 0$
#
# $p(y=1|x) = 0\quad\mathsf {if}\quad b_1x < 0$

# %% [markdown]
# $x =  Input$
#
# $b_0 = Bias $
#
# $W_1 = The \ weight \ vector$
#
# $y = The \ prediction, \ 1 \ if \ "yes" \ and \ 0 \ if \ "no"$

# %% [markdown]
# $J = -\frac{1}{m}\sum_{i=1}^{m}y^{(i)}\log(a^{(i)})+(1-y^{(i)})\log(1-a^{(i)})$

# %% [markdown]
# $K_{total} = \sum_{i=1}^n K_c^i$

# %% [markdown]
# $L = L_{cls} + L_{box} + L_{mask}$

# %% [markdown]
# ${Error}$ = ${Cal. \ Ground \ Truth} - {Prediction \ Cal.}$ * $\frac{100}{Cal. \ Ground \ Truth}$

# %% [markdown]
# ${Accuracy}$ = ${100} - {Error}$

# %% [markdown]
# ${Area \ of \ Object}$ = $\frac{Area \ of \ Piring}{Area \ of \ Piring \ (Prediction)}$ ${Area \ of \ Object \ (Prediction)}$

# %% [markdown]
# ${Volume \ Obyek}$ = ${Luas \ Obyek \ Sesungguhnya}$ *  ${Tinggi \ Obyek}$

# %% [markdown]
# ${Massa \ Obyek}$ = ${Massa \ Jenis \ Obyek} * {Volume \ Obyek}$

# %% [markdown]
# ${Cal. \ of \ Object}$ = $\frac{Mass \ of \ Object}{Mass \ of \ Object \  (Cal. \ Table) }$ ${Cal. \ of \ Object \ (Cal. \ Table)}$
